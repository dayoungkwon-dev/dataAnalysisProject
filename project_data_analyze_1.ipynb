# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

from matplotlib import font_manager, rc
font_location='c:/Windows/fonts/malgun.ttf' #폰트 위치 확인
font_name=font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)

# %%
one_person_df_2022 = pd.read_csv('dataset/1인가구(연령별)_2022년.csv', index_col=1)

one_person_df_2022
# Out:
#            년도       계
# 연령
# 20세미만   2022년   12872
# 20~29세  2022년  405309
# 30~39세  2022년  358392
# 40~49세  2022년  193725
# 50~59세  2022년  180239
# 60~69세  2022년  200139
# 70~79세  2022년  133350
# 80세이상   2022년   80161

# %%
one_person_df_2022.plot(kind='bar',grid=True)
# Out:
# <Axes: xlabel='연령'>

# %%
household_members_df = pd.read_csv('dataset/가구원수별_연도별_데이터.csv',index_col=0)

household_members_df.plot(grid=True)
# Out:
# <Axes: xlabel='시점'>
